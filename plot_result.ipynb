# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('csv/k200_subset.csv', sep='\t')

# gca stands for 'get current axis'
ax = plt.gca()

k = 200
result['x'] = list(range(k, 10 * k + 1, k))

result.plot(kind='line', use_index=True, x='x', y='2k', color='red', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='10k', color='black', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='20k', color='blue', ax=ax)

plt.xlabel('Number of labeled images')
plt.ylabel('R-squared')

plt.xticks(np.arange(k, 10 * k + 1, step=k))

plt.savefig('fig/result-k200-subset-ll4al.png', dpi=300)
plt.show()

# %%
result = pd.read_csv('csv/k200_margin.csv', sep='\t')

# gca stands for 'get current axis'
ax = plt.gca()

k = 200
result['x'] = list(range(k, 10 * k + 1, k))

result.plot(kind='line', use_index=True, x='x', y='0.01', color='red', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='0.1', color='black', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='1', color='blue', ax=ax)

plt.xlabel('Number of labeled images')
plt.ylabel('R-squared')

plt.xticks(np.arange(k, 10 * k + 1, step=k))

plt.savefig('fig/result-k200-margin-subset10k-ll4al.png', dpi=300)
plt.show()

# %%
result = pd.read_csv('csv/k200_m0.5_subset.csv', sep='\t')

# gca stands for 'get current axis'
ax = plt.gca()

k = 200
result['x'] = list(range(k, 10 * k + 1, k))

result.plot(kind='line', use_index=True, x='x', y='2k', color='red', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='10k', color='black', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='20k', color='blue', ax=ax)

plt.xlabel('Number of labeled images')
plt.ylabel('R-squared')

plt.xticks(np.arange(k, 10 * k + 1, step=k))

plt.savefig('fig/result-k200-m0.5-subset-ll4al.png', dpi=300)
plt.show()

# %%
result = pd.read_csv('csv/k200_s20k_margin.csv', sep='\t')

# gca stands for 'get current axis'
ax = plt.gca()

k = 200
result['x'] = list(range(k, 10 * k + 1, k))

result.plot(kind='line', use_index=True, x='x', y='0.1', color='red', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='0.5', color='black', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='1', color='blue', ax=ax)

plt.xlabel('Number of labeled images')
plt.ylabel('R-squared')

plt.xticks(np.arange(k, 10 * k + 1, step=k))

plt.savefig('fig/result-k200-s20k-ll4al.png', dpi=300)
plt.show()

# %%
result = pd.read_csv('csv/k200_m0.1_s20k_init.csv', sep='\t')

# gca stands for 'get current axis'
ax = plt.gca()

k = 200
result['x'] = list(range(k, 10 * k + 1, k))

result.plot(kind='line', use_index=True, x='x', y='random', color='black', linestyle='dashed', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='random-init', label='random+init', color='black', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='ll', color='red', linestyle='dashed', ax=ax)
result.plot(kind='line', use_index=True, x='x', y='ll-init', label='ll+init', color='red', ax=ax)
# result.plot(kind='line', use_index=True, x='x', y='tor', color='red', ax=ax)

plt.xlabel('Number of labeled images')
plt.ylabel('R-squared')

plt.xticks(np.arange(k, 10 * k + 1, step=k))
plt.ylim([0.6, 0.9])

plt.savefig('fig/result-k200-s20k-compare-baseline.png', dpi=300)
plt.show()
